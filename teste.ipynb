# %%
# %run ./config_ambiente

# %%
print(env)
print(source_path)
print(bronze_processing)
print(db_origem)
print(catalogo_bronze)

# %%
notebook_path = "./select_test"
dbutils.notebook.run(notebook_path, 3600, {
    "source_path": source_path,
    "bronze_processing": bronze_processing,
    "db_origem": db_origem,
    "catalogo_bronze": catalogo_bronze,
})
