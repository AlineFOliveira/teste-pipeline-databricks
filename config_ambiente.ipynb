# %%
# Se rodar na mão, assume homologacao
dbutils.widgets.text("env", "homologacao")
env = dbutils.widgets.get("env")

if env == "producao":
    source_path = "gs://prod-portal-processed/processing/"
    bronze_processing = "/Volumes/bronze/default/processing/"
    db_origem = "producao_portal_inteligencia"
    catalogo_bronze = "bronze"
elif env == "homologacao":
    source_path = "gs://hom-portal-processed/processing/"
    bronze_processing = "/Volumes/hom_bronze/default/processing/"
    db_origem = "homologacao_portal_inteligencia"
    catalogo_bronze = "hom_bronze"
else:
    # Default (hom)
    source_path = "gs://hom-portal-processed/processing/"
    bronze_processing = "/Volumes/hom_bronze/default/processing/"
    db_origem = "homologacao_portal_inteligencia"
    catalogo_bronze = "hom_bronze"
