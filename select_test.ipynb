# %%
source_path = dbutils.widgets.text("source_path", "homologacao")
bronze_processing = dbutils.widgets.text("bronze_processing", "/Volumes/bronze/default/processing/")
db_origem = dbutils.widgets.text("db_origem", "homologacao_portal_inteligencia")
catalogo_bronze = dbutils.widgets.text("catalogo_bronze", "hom_bronze")

# %%
print(source_path)
print(catalogo_bronze)

# %%
sqlCreate = f"""
    CREATE TABLE IF NOT EXISTS {catalogo_bronze}.catalogo_bronze (
    id STRING,
    texto STRING
    )
}
"""
spark.sql(sqlCreate)
