# %%
# Define valores de fallback
dbutils.widgets.text("source_path", "homologacao")
dbutils.widgets.text("bronze_processing", "/Volumes/bronze/default/processing/")
dbutils.widgets.text("db_origem", "homologacao_portal_inteligencia")
dbutils.widgets.text("catalogo_bronze", "hom_bronze")

# Pega os valores 
source_path = dbutils.widgets.get("source_path")
bronze_processing = dbutils.widgets.get("bronze_processing")
db_origem = dbutils.widgets.get("db_origem")
catalogo_bronze = dbutils.widgets.get("catalogo_bronze")

# %%
print(source_path)
print(catalogo_bronze)

# %%
sqlCreate = f"""
    CREATE TABLE IF NOT EXISTS {catalogo_bronze}.default.tabela_teste (
    id STRING,
    texto STRING
    )
"""
spark.sql(sqlCreate)
